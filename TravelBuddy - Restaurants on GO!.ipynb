# %%
# Importing the required libraries
import urllib.request, json
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import math
import requests
import json
import folium

#Google Maps Directions API endpoint
endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'
api_key = 'AIzaSyBcyYANyaRQWJKMlUsPkoT8yPvckf_oI0U'

#Asks the user to input Where they are and where they want to go.
origin = input('Where are you now?: ').replace(' ','+')
destination = input('Where do you want to go?: ').replace(' ','+')

#Building the URL for the request
nav_request = 'origin={}&destination={}&key={}'.format(origin,destination,api_key)
request = endpoint + nav_request

#Sends the request and reads the response.
response = urllib.request.urlopen(request).read()

#Loads response as JSON
directions = json.loads(response)
#print(directions)

routes = directions['routes']
routes

# To obtain latitude and longitude
source_latitude = routes[0]['legs'][0]['start_location']['lat']
source_longitude = routes[0]['legs'][0]['start_location']['lng']
dest_latitude = routes[0]['legs'][0]['end_location']['lat']
dest_longitude = routes[0]['legs'][0]['end_location']['lng']

print(f"\n\n\nyour current  co-ordinates are \n\t Latitude  : {source_latitude} \n\t longitude : {source_longitude}")
print(f"\n\n\nyour destination co-ordinates are \n\t Latitude  : {dest_latitude} \n\t longitude : {dest_longitude}")

print("\n\n\n\ncalculating the midpoint of the journey \n. \n. \n. \n. \n. \n. \n.")

import sys
sys.path.append("/usr/local/lib/python/site-packages")
from geographiclib.geodesic import Geodesic


def midpoint(x1, y1, x2, y2):
    
    # Define the path from 1 to 2
    l = Geodesic.WGS84.InverseLine(x1, y1, x2, y2)

    # Compute the midpoint
    m = l.Position(0.5 * l.s13)
    #print(m['lat2'],m['lon2'])
    return [round(m['lat2'], 7), round(m['lon2'], 7)]

mid_lat, mid_lon = midpoint(source_latitude,source_longitude,dest_latitude,dest_longitude)
print(f"your midpoint co-ordinates are \n\t Latitude  : {mid_lat} \n\t longitude : {mid_lon}")

def get_hotels(lat,lon):

    # Define a business ID
    business_id = 'eNl0VYhOAlL9Pi9rSZG9hw'
    unix_time = 1546047836

    # Define my API Key, My Endpoint, and My Header
    API_KEY = 'X4GONbIPUjiWuSAh8Vt2pAIhg5JljLLT-_FFwe2jummKx_wLUEI2cFPM4CKDI-qU1jeTcPV6p3YSFg_RY9PYq2kMgWuEkmDy88xHk1PuK9AE9CbzTSubPdO1JjXaXHYx'
    ENDPOINT = 'https://api.yelp.com/v3/businesses/search'
    HEADERS = {'Authorization': 'bearer %s' % API_KEY}

    # Define my parameters of the search
    # BUSINESS SEARCH PARAMETERS - EXAMPLE
    PARAMETERS = {'term': 'restaurants',
                  'latitude': lat,
                  'longitude' : lon,
                  'radius': 25000,
                  'categories' : "food, All",
                  'limit': 50,
                  'offset': 50,
                  'sort_by' : 'distance'
                 }

    # Make a request to the Yelp API
    response = requests.get(url = ENDPOINT,
                            params = PARAMETERS,
                            headers = HEADERS)

    # Convert the JSON String
    business_data = response.json()
    business_data

    a = json_normalize(business_data['businesses'])
    columns = ['name','location.display_address','rating','distance','is_closed','coordinates.latitude','coordinates.longitude']
    result = a.reindex(columns=columns)
    return result

source_df = get_hotels(source_latitude, source_longitude)
dest_df = get_hotels(dest_latitude, dest_longitude)
mid_df = get_hotels(mid_lat, mid_lon)

frames = [source_df,dest_df,mid_df]
final_dataframe = pd.concat(frames).reset_index(drop=True).sort_values(by=['rating', 'distance'], ascending=[False, True])

def set_value(row_number, assigned_value): 
    return assigned_value[row_number] 

color_dictionary ={5 : 'green', 4.5:'green', 4:'green', 3.5:'orange', 3:'orange',2.5:'orange',2:'red',1.5:'red', 1:'red', 0.5:'red', 0.0:'red'} 
final_dataframe['color'] = final_dataframe['rating'].apply(set_value, args =(color_dictionary, )) 

icon_dictionary = {'green':'thumbs-up', 'orange':'thumbs-up', 'red':'thumbs-down'}
final_dataframe['icon'] = final_dataframe['color'].apply(set_value, args =(icon_dictionary, ))

final_dataframe['popup'] = final_dataframe['name'].map(str) + '                    ' + final_dataframe['location.display_address'].map(str) + '                        ' + round(final_dataframe['distance']).map(str) + ' metres'

##### Creating maps 
from collections import namedtuple
p1 = [source_latitude, source_longitude]
p2 = [dest_latitude, dest_longitude]

def get_arrows(locations, color='blue', size=8, n_arrows=4):
    
    '''
    Get a list of correctly placed and rotated 
    arrows/markers to be plotted
    
    Parameters
    locations : list of lists of lat lons that represent the 
                start and end of the line. 
                eg [[41.1132, -96.1993],[41.3810, -95.8021]]
    arrow_color : default is 'blue'
    size : default is 6
    n_arrows : number of arrows to create.  default is 3
    Return
    list of arrows/markers
    '''
    
    Point = namedtuple('Point', field_names=['lat', 'lon'])
    
    # creating point from our Point named tuple
    p1 = Point(locations[0][0], locations[0][1])
    p2 = Point(locations[1][0], locations[1][1])
    
    # getting the rotation needed for our marker.  
    # Subtracting 90 to account for the marker's orientation
    # of due East(get_bearing returns North)
    rotation = get_bearing(p1, p2) - 90
    
    # get an evenly space list of lats and lons for our arrows
    # note that I'm discarding the first and last for aesthetics
    # as I'm using markers to denote the start and end
    arrow_lats = np.linspace(p1.lat, p2.lat, n_arrows + 2)[1:n_arrows+1]
    arrow_lons = np.linspace(p1.lon, p2.lon, n_arrows + 2)[1:n_arrows+1]
    
    arrows = []
    
    #creating each "arrow" and appending them to our arrows list
    for points in zip(arrow_lats, arrow_lons):
        arrows.append(folium.RegularPolygonMarker(location=points, 
                      fill_color=color, number_of_sides=3, 
                      radius=size, rotation=rotation).add_to(m))
    return arrows

def get_bearing(p1, p2):
    
    '''
    Returns compass bearing from p1 to p2
    
    Parameters
    p1 : namedtuple with lat lon
    p2 : namedtuple with lat lon
    
    Return
    compass bearing of type float
    
    Notes
    Based on https://gist.github.com/jeromer/2005586
    '''
    
    long_diff = np.radians(p2.lon - p1.lon)
    
    lat1 = np.radians(p1.lat)
    lat2 = np.radians(p2.lat)
    
    x = np.sin(long_diff) * np.cos(lat2)
    y = (np.cos(lat1) * np.sin(lat2) 
        - (np.sin(lat1) * np.cos(lat2) 
        * np.cos(long_diff)))
    bearing = np.degrees(np.arctan2(x, y))
    
    # adjusting for compass bearing
    if bearing < 0:
        return bearing + 360
    return bearing

m = folium.Map(
        location=[mid_lat, mid_lon],
        zoom_start=4,
        tiles='Stamen Terrain'
    )

def get_map(dataframe):
    

    for index, row in dataframe.iterrows():

        folium.Marker([row['coordinates.latitude'],row['coordinates.longitude']],
                      popup=row['popup'],
                      icon=folium.Icon(icon=row['icon'],color=row['color'])
                       ).add_to(m)
        folium.Marker(location=[mid_lat, mid_lon],
                      popup='middle_point',
                      icon=folium.Icon(color='red', icon='centrecode')
                      ).add_to(m)
        folium.PolyLine(locations=[p1, p2], color='blue').add_to(m)
        arrows = get_arrows(locations=[p1, p2], n_arrows=4)
    for arrow in arrows:
        arrow.add_to(m)

    m.save('hotel_map.html')
    return m 
get_map(final_dataframe)
# Out:
# Where are you now?: Buffalo
# Where do you want to go?: Syracuse
#
#
#
# your current  co-ordinates are
# 	 Latitude  : 42.8864931
# 	 longitude : -78.8787931
#
#
#
# your destination co-ordinates are
# 	 Latitude  : 43.0481227
# 	 longitude : -76.1474497
#
#
#
#
# calculating the midpoint of the journey
# .
# .
# .
# .
# .
# .
# .
# your midpoint co-ordinates are
# 	 Latitude  : 42.975456
# 	 longitude : -77.5149095
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
final_dataframe
# Out:
#                                             name  \
# 0                    Perks Cafe at Horsefeathers
# 14                           Pattaya Street Food
# 22                            Kathrene’s Cuisine
# 40                                La Verdad Cafe
# 59                         The Cookie Connection
# 49                                  Hearty House
# 101             Donna Marie's Gluten Free Bakery
# 120                Highland Market Bakery & Deli
# 127                       Caramel Bakery and Bar
# 140                           Cornerstone Market
# 1                        Breadhive Bakery & Cafe
# 2                            Westside Tilth Farm
# 5                               Master Food Mart
# 10                            Five Points Bakery
# 15                          Thang's Family Ramen
# 26                            Vaticano Fort Erie
# 27                                     Solo Eats
# 29                                Guercio & Sons
# 32                   Ashker's Juice Bar and Cafe
# 33                       Buffalo's Golden Corner
# 35                                 Slavic Bazzar
# 39                            Ashker's Blackrock
# 52                          Mitsuba Ramen Noodle
# 44                                   Donut Kraze
# 57                                   Tim Hortons
# 45                               You Crack Me Up
# 62                Hope Cafe Coffee and Tea House
# 64                                   Cafe at 407
# 73                Toss 'n' Fire Wood-Fired Pizza
# 76                        Deborah's Sweet Treats
# ..                                           ...
# 51                                Sonic Drive-In
# 54                                    McDonald's
# 56                                    McDonald's
# 47                                  NOCO Express
# 67                             Bruegger's Bagels
# 80                                    McDonald's
# 90                             Bruegger's Bagels
# 92                          Warners Service Area
# 109                                   McDonald's
# 110                                   McDonald's
# 116                                   McDonald's
# 131                            Bruegger's Bagels
# 134                                   McDonald's
# 141  Marvin Mozzeroni's Pizza & Pasta Restaurant
# 41                                    McDonald's
# 61                                    McDonald's
# 65                                Sonic Drive-In
# 77                                 Dunkin Donuts
# 96                                Cam's Pizzeria
# 115                                   McDonald's
# 12                                    McDonald's
# 18                                    McDonald's
# 19                                   Tim Hortons
# 36                                    McDonald's
# 55                                    McDonald's
# 58                                    McDonald's
# 63                                    McDonald's
# 93                                    McDonald's
# 144                                   McDonald's
# 71                                    McDonald's
#
#                               location.display_address  rating      distance  \
# 0              [346 Connecticut St, Buffalo, NY 14213]     5.0   2287.007869
# 14   [25 Grant St, West Side Bazaar, Buffalo, NY 14...     5.0   3289.040591
# 22   [999 Broadway St., The Broadway Market, Buffal...     5.0   3431.184544
# 40              [1132 E Lovejoy St, Buffalo, NY 14206]     5.0   5910.400024
# 59             [2803 Brewerton Rd, Syracuse, NY 13211]     5.0   6586.759783
# 49            [2181 Clinton St, West Seneca, NY 14206]     5.0   6958.651690
# 101            [1694 Penfield Rd, Rochester, NY 14625]     5.0  17413.228417
# 120                   [830 S Ave, Rochester, NY 14620]     5.0  19610.228321
# 127                [647 Park Ave, Rochester, NY 14607]     5.0  19878.882481
# 140                  [8732 Main St, Honeoye, NY 14471]     5.0  20607.521351
# 1              [402 Connecticut St, Buffalo, NY 14213]     4.5   2328.507965
# 2                  [246 Normal Ave, Buffalo, NY 14213]     4.5   2405.610103
# 5                [129 Louisiana St, Buffalo, NY 14204]     4.5   2563.581674
# 10                  [44 Brayton St, Buffalo, NY 14213]     4.5   2759.787914
# 15                    [25 Grant St, Buffalo, NY 14213]     4.5   3301.508392
# 26   [90 Niagara Boulevard, Fort Erie, ON L2A 3G3, ...     4.5   3679.520942
# 27                 [261 E Ferry St, Buffalo, NY 14208]     4.5   3729.921271
# 29                   [250 Grant St, Buffalo, NY 14213]     4.5   3927.960800
# 32               [1002 Elmwood Ave, Buffalo, NY 14222]     4.5   4218.292593
# 33             [1715 Jefferson Ave, Buffalo, NY 14208]     4.5   4443.251112
# 35                [1550 William St, Buffalo, NY 14206]     4.5   5333.949721
# 39                 [414 Amherst St, Buffalo, NY 14207]     4.5   5880.517463
# 52              [3206 Erie Blvd E, Syracuse, NY 13214]     4.5   6012.230577
# 44                 [406 Dingens St, Buffalo, NY 14206]     4.5   6440.175726
# 57             [3328 W Genesee St, Syracuse, NY 13219]     4.5   6443.107480
# 45                                 [Buffalo, NY 14220]     4.5   6605.895000
# 62           [305 Vine St, Ste 5, Liverpool, NY 13088]     4.5   7720.252358
# 64                 [407 Tulip St, Liverpool, NY 13088]     4.5   7938.506587
# 73           [315 N Main St, North Syracuse, NY 13212]     4.5  10277.899501
# 76               [7421 Oswego Rd, Liverpool, NY 13090]     4.5  10849.830630
# ..                                                 ...     ...           ...
# 51                [3170 Erie Blvd E, Dewitt, NY 13214]     2.5   5866.277599
# 54               [6031 Tarbell Rd, Syracuse, NY 13206]     2.5   6097.247010
# 56              [6481 Thompson Rd, Syracuse, NY 13206]     2.5   6224.516538
# 47                [2133 S Park Ave, Buffalo, NY 14220]     2.5   6764.317806
# 67                [5198 W Taft Rd, Syracuse, NY 13212]     2.5   8217.480123
# 80               [7893 Brewerton Rd, Cicero, NY 13039]     2.5  11707.938157
# 90                [112 E Seneca St, Manlius, NY 13104]     2.5  14702.922907
# 92                 [I-90 Westbound, Warners, NY 13164]     2.5  14800.805450
# 109             [2191 Penfield Rd, Penfield, NY 14526]     2.5  18253.190750
# 110      [1422-32 Mount Hope Ave, Rochester, NY 14620]     2.5  18323.263745
# 116                    [250 E Main St, Avon, NY 14414]     2.5  19313.752779
# 131              [548 Monroe Ave, Rochester, NY 14607]     2.5  19997.670861
# 134              [420 Monroe Ave, Rochester, NY 14607]     2.5  20241.869558
# 141                   [129 Main St, Macedon, NY 14502]     2.5  20666.305960
# 41               [1830 Genessee St, Buffalo, NY 14211]     2.0   6019.835550
# 61                 [6105 S Salina, Syracuse, NY 13205]     2.0   7262.288350
# 65       [3808 Brewerton Rd, North Syracuse, NY 13212]     2.0   7950.950959
# 77              [4744 Buckley Rd, Liverpool, NY 13088]     2.0  10855.541795
# 96               [3610 Rt 31, Baldwinsville, NY 13027]     2.0  17274.743499
# 115               [1701 East Ave, Rochester, NY 14610]     2.0  19291.245532
# 12                   [1338 Main St, Buffalo, NY 14209]     1.5   2800.700940
# 18                 [241 W Ferry St, Buffalo, NY 14213]     1.5   3364.430017
# 19       [1088 Niagara St, Ste 100, Buffalo, NY 14213]     1.5   3377.158739
# 36            [1028 Mc Kinley Pkwy, Buffalo, NY 14220]     1.5   5402.723960
# 55               [3207 Erie Blvd E, De Witt, NY 13214]     1.5   6102.949929
# 58             [3329 W Genesee St, Syracuse, NY 13219]     1.5   6548.769218
# 63       [3806 Brewerton Rd, North Syracuse, NY 13212]     1.5   7883.602629
# 93              [2660 Brickyard Rd, Warners, NY 13164]     1.5  14804.817753
# 144               [820 Culver Rd, Rochester, NY 14609]     1.5  20942.664721
# 71             [5288 W Genesee St, Camillus, NY 13031]     1.0  10019.400343
#
#      is_closed  coordinates.latitude  coordinates.longitude   color  \
# 0        False             42.905850             -78.888290   green
# 14       False             42.914856             -78.890389   green
# 22       False             42.893166             -78.837673   green
# 40       False             42.890030             -78.806400   green
# 59       False             43.107350             -76.148857   green
# 49       False             42.871420             -78.795910   green
# 101      False             43.130860             -77.487290   green
# 120      False             43.139010             -77.605530   green
# 127      False             43.148120             -77.578390   green
# 140      False             42.790130             -77.516247   green
# 1        False             42.906660             -78.886540   green
# 2        False             42.906720             -78.889260   green
# 5        False             42.865310             -78.866310   green
# 10       False             42.910920             -78.885660   green
# 15       False             42.914968             -78.890273   green
# 26       False             42.910970             -78.909080   green
# 27       False             42.914767             -78.854154   green
# 29       False             42.920654             -78.890778   green
# 32       False             42.924400             -78.877250   green
# 33       False             42.921990             -78.853690   green
# 35       False             42.885036             -78.813355   green
# 39       False             42.938930             -78.888690   green
# 52       False             43.051586             -76.073356   green
# 44       False             42.877944             -78.800537   green
# 57       False             43.049270             -76.226940   green
# 45       False             42.844710             -78.823690   green
# 62       False             43.102200             -76.207150   green
# 64       False             43.104021             -76.208249   green
# 73       False             43.139515             -76.128527   green
# 76       False             43.129494             -76.221185   green
# ..         ...                   ...                    ...     ...
# 51       False             43.053130             -76.075660  orange
# 54       False             43.091148             -76.100916  orange
# 56       False             43.085718             -76.090678  orange
# 47       False             42.840645             -78.824089  orange
# 67       False             43.121676             -76.157263  orange
# 80       False             43.152160             -76.125256  orange
# 90       False             43.001076             -75.978416  orange
# 92       False             43.092189             -76.319384  orange
# 109      False             43.130399             -77.440713  orange
# 110      False             43.121791             -77.618586  orange
# 116      False             42.910743             -77.735102  orange
# 131      False             43.146118             -77.592552  orange
# 134      False             43.147772             -77.595252  orange
# 141      False             43.069330             -77.295470  orange
# 41       False             42.912779             -78.814185     red
# 61       False             42.982910             -76.142543     red
# 65       False             43.119554             -76.143010     red
# 77       False             43.141293             -76.186847     red
# 96       False             43.179473             -76.261095     red
# 115      False             43.145640             -77.559120     red
# 12       False             42.910138             -78.866946     red
# 18       False             42.915015             -78.892579     red
# 19       False             42.912486             -78.900239     red
# 36       False             42.858000             -78.825091     red
# 55       False             43.051930             -76.072549     red
# 58       False             43.048020             -76.228200     red
# 63       False             43.118953             -76.143171     red
# 93       False             43.091523             -76.322496     red
# 144      False             43.160084             -77.565856     red
# 71       False             43.041412             -76.268641     red
#
#             icon                                              popup
# 0      thumbs-up  Perks Cafe at Horsefeathers                   ...
# 14     thumbs-up  Pattaya Street Food                    ['25 Gr...
# 22     thumbs-up  Kathrene’s Cuisine                    ['999 Br...
# 40     thumbs-up  La Verdad Cafe                    ['1132 E Lov...
# 59     thumbs-up  The Cookie Connection                    ['280...
# 49     thumbs-up  Hearty House                    ['2181 Clinton...
# 101    thumbs-up  Donna Marie's Gluten Free Bakery              ...
# 120    thumbs-up  Highland Market Bakery & Deli                 ...
# 127    thumbs-up  Caramel Bakery and Bar                    ['64...
# 140    thumbs-up  Cornerstone Market                    ['8732 M...
# 1      thumbs-up  Breadhive Bakery & Cafe                    ['4...
# 2      thumbs-up  Westside Tilth Farm                    ['246 N...
# 5      thumbs-up  Master Food Mart                    ['129 Loui...
# 10     thumbs-up  Five Points Bakery                    ['44 Bra...
# 15     thumbs-up  Thang's Family Ramen                    ['25 G...
# 26     thumbs-up  Vaticano Fort Erie                    ['90 Nia...
# 27     thumbs-up  Solo Eats                    ['261 E Ferry St'...
# 29     thumbs-up  Guercio & Sons                    ['250 Grant ...
# 32     thumbs-up  Ashker's Juice Bar and Cafe                   ...
# 33     thumbs-up  Buffalo's Golden Corner                    ['1...
# 35     thumbs-up  Slavic Bazzar                    ['1550 Willia...
# 39     thumbs-up  Ashker's Blackrock                    ['414 Am...
# 52     thumbs-up  Mitsuba Ramen Noodle                    ['3206...
# 44     thumbs-up  Donut Kraze                    ['406 Dingens S...
# 57     thumbs-up  Tim Hortons                    ['3328 W Genese...
# 45     thumbs-up  You Crack Me Up                    ['Buffalo, ...
# 62     thumbs-up  Hope Cafe Coffee and Tea House                ...
# 64     thumbs-up  Cafe at 407                    ['407 Tulip St'...
# 73     thumbs-up  Toss 'n' Fire Wood-Fired Pizza                ...
# 76     thumbs-up  Deborah's Sweet Treats                    ['74...
# ..           ...                                                ...
# 51     thumbs-up  Sonic Drive-In                    ['3170 Erie ...
# 54     thumbs-up  McDonald's                    ['6031 Tarbell R...
# 56     thumbs-up  McDonald's                    ['6481 Thompson ...
# 47     thumbs-up  NOCO Express                    ['2133 S Park ...
# 67     thumbs-up  Bruegger's Bagels                    ['5198 W ...
# 80     thumbs-up  McDonald's                    ['7893 Brewerton...
# 90     thumbs-up  Bruegger's Bagels                    ['112 E S...
# 92     thumbs-up  Warners Service Area                    ['I-90...
# 109    thumbs-up  McDonald's                    ['2191 Penfield ...
# 110    thumbs-up  McDonald's                    ['1422-32 Mount ...
# 116    thumbs-up  McDonald's                    ['250 E Main St'...
# 131    thumbs-up  Bruegger's Bagels                    ['548 Mon...
# 134    thumbs-up  McDonald's                    ['420 Monroe Ave...
# 141    thumbs-up  Marvin Mozzeroni's Pizza & Pasta Restaurant   ...
# 41   thumbs-down  McDonald's                    ['1830 Genessee ...
# 61   thumbs-down  McDonald's                    ['6105 S Salina'...
# 65   thumbs-down  Sonic Drive-In                    ['3808 Brewe...
# 77   thumbs-down  Dunkin Donuts                    ['4744 Buckle...
# 96   thumbs-down  Cam's Pizzeria                    ['3610 Rt 31...
# 115  thumbs-down  McDonald's                    ['1701 East Ave'...
# 12   thumbs-down  McDonald's                    ['1338 Main St',...
# 18   thumbs-down  McDonald's                    ['241 W Ferry St...
# 19   thumbs-down  Tim Hortons                    ['1088 Niagara ...
# 36   thumbs-down  McDonald's                    ['1028 Mc Kinley...
# 55   thumbs-down  McDonald's                    ['3207 Erie Blvd...
# 58   thumbs-down  McDonald's                    ['3329 W Genesee...
# 63   thumbs-down  McDonald's                    ['3806 Brewerton...
# 93   thumbs-down  McDonald's                    ['2660 Brickyard...
# 144  thumbs-down  McDonald's                    ['820 Culver Rd'...
# 71   thumbs-down  McDonald's                    ['5288 W Genesee...
#
# [150 rows x 10 columns]
